# %% [markdown]
# <a href="https://colab.research.google.com/github/prabuddhayogi/ai-with-python/blob/numpy/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a=[(1,2,3),(4,5,6)]
b=np.resize(-1)
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3495378444.py in <cell line: 0>()
#       1 a=[(1,2,3),(4,5,6)]
# ----> 2 b=np.resize(-1)
#       3 b
#
# TypeError: resize() missing 1 required positional argument: 'new_shape'
